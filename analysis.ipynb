# %%
import pandas as pd

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df['director'].value_counts()
# Out:
# director
# Not Given                 2588
# Rajiv Chilaka               20
# Alastair Fothergill         18
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
#                           ...
# Mark Risley                  1
# Kirati Nakintanon            1
# Christian De Vita            1
# Abu Bakr Shawky              1
# N. Chandra                   1
# Name: count, Length: 4528, dtype: int64

# %%
import numpy as np

# %%
df['director'] = df['director'].replace('Not Given', np.nan)

# %%
df.tail()
# Out:
#      show_id     type               title director        country  date_added  \
# 8785   s8797  TV Show          Yunus Emre      NaN         Turkey   1/17/2017
# 8786   s8798  TV Show           Zak Storm      NaN  United States   9/13/2018
# 8787   s8801  TV Show  Zindagi Gulzar Hai      NaN       Pakistan  12/15/2016
# 8788   s8784  TV Show                Yoko      NaN       Pakistan   6/23/2018
# 8789   s8786  TV Show                 YOM      NaN       Pakistan    6/7/2018
#
#       release_year rating   duration  \
# 8785          2016  TV-PG  2 Seasons
# 8786          2016  TV-Y7  3 Seasons
# 8787          2012  TV-PG   1 Season
# 8788          2016   TV-Y   1 Season
# 8789          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      6202 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df_limpio = df.dropna(subset=['director'])

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6202 entries, 0 to 6569
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6202 non-null   object
#  1   type          6202 non-null   object
#  2   title         6202 non-null   object
#  3   director      6202 non-null   object
#  4   country       6202 non-null   object
#  5   date_added    6202 non-null   object
#  6   release_year  6202 non-null   int64
#  7   rating        6202 non-null   object
#  8   duration      6202 non-null   object
#  9   listed_in     6202 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 533.0+ KB

# %%
df_limpio['country'].value_counts()
# Out:
# country
# United States     2401
# India              975
# United Kingdom     406
# Not Given          287
# Canada             189
#                   ...
# Slovenia             1
# Guatemala            1
# Jamaica              1
# Somalia              1
# Croatia              1
# Name: count, Length: 79, dtype: int64

# %%
moda_pais = df_limpio['country'].mode()[0]

# %%
print(moda_pais)
# Out:
# United States

# %%
df_limpio.loc['country'] = df_limpio['country'].replace('Not Given', moda_pais)
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_26168\4169248131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio.loc['country'] = df_limpio['country'].replace('Not Given', moda_pais)

# %%
df_limpio['country'].value_counts()
# Out:
# country
# United States     2401
# India              975
# United Kingdom     406
# Not Given          287
# Canada             189
#                   ...
# Slovenia             1
# Guatemala            1
# Jamaica              1
# Somalia              1
# Croatia              1
# Name: count, Length: 79, dtype: int64

# %%
df_limpio.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021        2020.0  PG-13    90 min
# 1         France  9/24/2021        2021.0  TV-MA  1 Season
# 2  United States  9/24/2021        2021.0  TV-MA  1 Season
# 3         Brazil  9/22/2021        2021.0  TV-PG    91 min
# 4  United States  9/24/2021        1993.0  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df_limpio.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021        2020.0  PG-13    90 min
# 1         France  9/24/2021        2021.0  TV-MA  1 Season
# 2  United States  9/24/2021        2021.0  TV-MA  1 Season
# 3         Brazil  9/22/2021        2021.0  TV-PG    91 min
# 4  United States  9/24/2021        1993.0  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6203 entries, 0 to country
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6202 non-null   object
#  1   type          6202 non-null   object
#  2   title         6202 non-null   object
#  3   director      6202 non-null   object
#  4   country       6202 non-null   object
#  5   date_added    6202 non-null   object
#  6   release_year  6202 non-null   float64
#  7   rating        6202 non-null   object
#  8   duration      6202 non-null   object
#  9   listed_in     6202 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 533.1+ KB

# %%
df_limpio = df_limpio.dropna(subset=['release_year'])

# %%
df_limpio['release_year'].isna().sum()
# Out:
# np.int64(0)

# %%
df_limpio['release_year'] = df_limpio['release_year'].astype(int)

# %%
df_limpio.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6202 entries, 0 to 6569
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6202 non-null   object
#  1   type          6202 non-null   object
#  2   title         6202 non-null   object
#  3   director      6202 non-null   object
#  4   country       6202 non-null   object
#  5   date_added    6202 non-null   object
#  6   release_year  6202 non-null   int64
#  7   rating        6202 non-null   object
#  8   duration      6202 non-null   object
#  9   listed_in     6202 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 533.0+ KB

# %%
df_limpio['genero_principal'] = df_limpio['listed_in'].str.split(',').str[0]

# %%
df_limpio.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in          genero_principal
# 0                                      Documentaries             Documentaries
# ...
